# %% [markdown]
# # Importing the packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importiong dataset

# %%
data=pd.read_csv('digitaleye.csv')

# %%
data.head()
# Out:
#               Name  Age  Sex  wearables  Duration  onlineplatforms  Nature  \
# 0      Syeda Afiya   22    2          1         2                1       2
# 1          Hemanth   24    1          1         2                2       2
# 2          Kranthi   23    1          5         1                2       2
# 3   Sk.M.A.Khadeer   23    1          1         2                2       2
# 4  B.Shravan kumar   27    1          3         2                2       1
#
#    screenillumination  workingyears  hoursspentdailycurricular  ...  \
# 0                   2             1                          1  ...
# 1                   1             2                          1  ...
# 2                   3             3                          4  ...
# 3                   1             1                          1  ...
# 4                   1             1                          1  ...
#
#    freqquencyofcomplaints  Severityofcomplaints  Ocularsymptomsobservedlately  \
# 0                       1                     1                             5
# 1                       0                     0                             6
# 2                       1                     2                             5
# 3                       1                     1                             3
# 4                       0                     0                             7
#
#    Symptomsobservingatleasthalfofthetimes  Complaintsfrequency  \
# 0                                       3                    3
# 1                                       3                    1
# 2                                       3                    2
# 3                                       2                    3
# 4                                       2                    2
#
#    frequencyofdryeyes  Schimers1Lefteye  Schimers1righteye  Schimers2Lefteye  \
# 0                   2                12                 13                16
# 1                   1                25                 28                30
# 2                   1                 8                  6                 9
# 3                   1                13                 14                15
# 4                   3                34                 32                35
#
#    Schimers2righteye
# 0                 14
# 1                 32
# 2                  8
# 3                 14
# 4                 35
#
# [5 rows x 27 columns]

# %%
data.tail()
# Out:
#              Name  Age  Sex  wearables  Duration  onlineplatforms  Nature  \
# 295         Rahul   27    1          3         1                2       2
# 296  Ganesh Nayak   27    1          1         2                1       2
# 297  Nitin Sharma   24    1          3         1                1       2
# 298   Mukul Saner   24    1          1         1                1       2
# 299  D.Kiran goud   24    1          3         1                2       2
#
#      screenillumination  workingyears  hoursspentdailycurricular  ...  \
# 295                   3             1                          1  ...
# 296                   3             1                          1  ...
# 297                   3             1                          1  ...
# 298                   3             1                          1  ...
# 299                   2             1                          1  ...
#
#      freqquencyofcomplaints  Severityofcomplaints  \
# 295                       0                     0
# 296                       0                     0
# 297                       0                     0
# 298                       0                     2
# 299                       1                     0
#
#      Ocularsymptomsobservedlately  Symptomsobservingatleasthalfofthetimes  \
# 295                             1                                       4
# 296                             6                                       3
# 297                             6                                       2
# 298                             5                                       3
# 299                             4                                       2
#
#      Complaintsfrequency  frequencyofdryeyes  Schimers1Lefteye  \
# 295                    2                   2                23
# 296                    1                   2                26
# 297                    1                   2                23
# 298                    2                   2                12
# 299                    2                   2                16
#
#      Schimers1righteye  Schimers2Lefteye  Schimers2righteye
# 295                 26                29                 30
# 296                 22                27                 25
# 297                 27                28                 29
# 298                 14                16                 18
# 299                 19                19                 21
#
# [5 rows x 27 columns]

# %%
rows=len(data)
print(rows)
# Out:
# 300

# %%
cols=len(data.columns)
print(cols)
# Out:
# 27

# %%
data.describe()
# Out:
#               Age         Sex   wearables    Duration  onlineplatforms  \
# count  300.000000  300.000000  300.000000  300.000000       300.000000
# mean    22.173333    1.553333    2.353333    1.323333         1.650000
# std      2.774096    0.497978    1.407750    0.588737         0.477767
# min     17.000000    1.000000    1.000000    1.000000         1.000000
# 25%     20.000000    1.000000    1.000000    1.000000         1.000000
# 50%     22.000000    2.000000    2.000000    1.000000         2.000000
# 75%     24.000000    2.000000    3.000000    2.000000         2.000000
# max     28.000000    2.000000    5.000000    3.000000         2.000000
#
#            Nature  screenillumination  workingyears  \
# count  300.000000          300.000000    300.000000
# mean     1.833333            1.783333      1.566667
# std      0.373301            0.724434      0.730755
# min      1.000000            1.000000      1.000000
# 25%      2.000000            1.000000      1.000000
# 50%      2.000000            2.000000      1.000000
# 75%      2.000000            2.000000      2.000000
# max      2.000000            3.000000      3.000000
#
#        hoursspentdailycurricular  hoursspentdailynoncurricular  ...  \
# count                 300.000000                    300.000000  ...
# mean                    1.776667                      2.213333  ...
# std                     0.960833                      1.035081  ...
# min                     1.000000                      1.000000  ...
# 25%                     1.000000                      1.000000  ...
# 50%                     1.000000                      2.000000  ...
# 75%                     2.000000                      3.000000  ...
# max                     4.000000                      4.000000  ...
#
#        freqquencyofcomplaints  Severityofcomplaints  \
# count              300.000000            300.000000
# mean                 0.546667              0.596667
# std                  0.543575              0.674913
# min                  0.000000              0.000000
# 25%                  0.000000              0.000000
# 50%                  1.000000              0.000000
# 75%                  1.000000              1.000000
# max                  2.000000              2.000000
#
#        Ocularsymptomsobservedlately  Symptomsobservingatleasthalfofthetimes  \
# count                    300.000000                              300.000000
# mean                       5.193333                                3.303333
# std                        2.485265                                1.108491
# min                        0.000000                                1.000000
# 25%                        4.000000                                3.000000
# 50%                        5.000000                                3.000000
# 75%                        6.000000                                4.000000
# max                        9.000000                                5.000000
#
#        Complaintsfrequency  frequencyofdryeyes  Schimers1Lefteye  \
# count           300.000000          300.000000        300.000000
# mean              1.720000            2.083333         21.073333
# std               0.640025            0.671734          7.511059
# min               1.000000            1.000000          4.000000
# 25%               1.000000            2.000000         15.000000
# 50%               2.000000            2.000000         22.000000
# 75%               2.000000            3.000000         27.000000
# max               3.000000            3.000000         35.000000
#
#        Schimers1righteye  Schimers2Lefteye  Schimers2righteye
# count         300.000000        300.000000         300.000000
# mean           21.560000         25.376667          25.733333
# std             7.377975          7.105614           7.050384
# min             2.000000          8.000000           6.000000
# 25%            16.000000         20.000000          21.750000
# 50%            22.500000         28.000000          28.000000
# 75%            28.000000         31.000000          31.000000
# max            35.000000         35.000000          35.000000
#
# [8 rows x 26 columns]

# %%
# HERE COUNT FOR ALL VARIABLES SHOULD BE 300 BUT THERE ARE SOME VARIABLES WHICH ARE NOT 300

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Name                                    300 non-null    object
#  1   Age                                     300 non-null    int64
#  2   Sex                                     300 non-null    int64
#  3   wearables                               300 non-null    int64
#  4   Duration                                300 non-null    int64
#  5   onlineplatforms                         300 non-null    int64
#  6   Nature                                  300 non-null    int64
#  7   screenillumination                      300 non-null    int64
#  8   workingyears                            300 non-null    int64
#  9   hoursspentdailycurricular               300 non-null    int64
#  10  hoursspentdailynoncurricular            300 non-null    int64
#  11  Gadgetsused                             300 non-null    int64
#  12  levelofgadjetwithrespecttoeyes          300 non-null    int64
#  13  Distancekeptbetweeneyesandgadjet        300 non-null    int64
#  14  Avgnighttimeusageperday                 300 non-null    int64
#  15  Blinkingduringscreenusage               300 non-null    int64
#  16  Difficultyinfocusingafterusingscreens   300 non-null    int64
#  17  freqquencyofcomplaints                  300 non-null    int64
#  18  Severityofcomplaints                    300 non-null    int64
#  19  Ocularsymptomsobservedlately            300 non-null    int64
#  20  Symptomsobservingatleasthalfofthetimes  300 non-null    int64
#  21  Complaintsfrequency                     300 non-null    int64
#  22  frequencyofdryeyes                      300 non-null    int64
#  23  Schimers1Lefteye                        300 non-null    int64
#  24  Schimers1righteye                       300 non-null    int64
#  25  Schimers2Lefteye                        300 non-null    int64
#  26  Schimers2righteye                       300 non-null    int64
# dtypes: int64(26), object(1)
# memory usage: 63.4+ KB

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# # NULL VALUES

# %%
data.isnull().sum()
# Out:
# Name                                      0
# Age                                       0
# Sex                                       0
# wearables                                 0
# Duration                                  0
# onlineplatforms                           0
# Nature                                    0
# screenillumination                        0
# workingyears                              0
# hoursspentdailycurricular                 0
# hoursspentdailynoncurricular              0
# Gadgetsused                               0
# levelofgadjetwithrespecttoeyes            0
# Distancekeptbetweeneyesandgadjet          0
# Avgnighttimeusageperday                   0
# Blinkingduringscreenusage                 0
# Difficultyinfocusingafterusingscreens     0
# freqquencyofcomplaints                    0
# Severityofcomplaints                      0
# Ocularsymptomsobservedlately              0
# Symptomsobservingatleasthalfofthetimes    0
# Complaintsfrequency                       0
# frequencyofdryeyes                        0
# Schimers1Lefteye                          0
# Schimers1righteye                         0
# Schimers2Lefteye                          0
# Schimers2righteye                         0
# dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.isnull(),cmap='viridis')
plt.show()

# %%
missing_percentage=(data.isnull().sum() / len(data)) * 100
missing_info=pd.DataFrame({'Missing Percentage': missing_percentage})
missing_info=missing_info.sort_values(by='Missing Percentage',ascending=False)
missing_columns = missing_info[missing_info['Missing Percentage']>0]
if not missing_columns.empty:
    print(missing_columns)

# %%
# THIS SHOWS THERE IS NULL VALUES IN DATASET

# THE LINES ARE NULLS IN THE DATASETS

# %% [markdown]
# # OUTLIERS

# %%
for column in data.columns[2:]:
    unique_counts = data[column].value_counts()
    print(unique_counts)
    print("\n")
# Out:
# Sex
# 2    166
# 1    134
# Name: count, dtype: int64
#
#
# wearables
# 1    134
# 3     89
# 5     35
# 4     23
# 2     19
# Name: count, dtype: int64
#
#
# Duration
# 1    222
# 2     59
# 3     19
# Name: count, dtype: int64
#
#
# onlineplatforms
# 2    195
# 1    105
# Name: count, dtype: int64
#
#
# Nature
# 2    250
# 1     50
# Name: count, dtype: int64
#
#
# screenillumination
# 2    129
# 1    118
# 3     53
# Name: count, dtype: int64
#
#
# workingyears
# 1    173
# 2     84
# 3     43
# Name: count, dtype: int64
#
#
# hoursspentdailycurricular
# 1    158
# 2     72
# 3     49
# 4     21
# Name: count, dtype: int64
#
#
# hoursspentdailynoncurricular
# 2    98
# 1    91
# 3    67
# 4    44
# Name: count, dtype: int64
#
#
# Gadgetsused
# 1    253
# 2     31
# 3     16
# Name: count, dtype: int64
#
#
# levelofgadjetwithrespecttoeyes
# 2    219
# 1     81
# Name: count, dtype: int64
#
#
# Distancekeptbetweeneyesandgadjet
# 2    187
# 1     93
# 3     20
# Name: count, dtype: int64
#
#
# Avgnighttimeusageperday
# 2    121
# 1     78
# 3     73
# 4     28
# Name: count, dtype: int64
#
#
# Blinkingduringscreenusage
# 2    168
# 1    132
# Name: count, dtype: int64
#
#
# Difficultyinfocusingafterusingscreens
# 2    147
# 3     89
# 1     64
# Name: count, dtype: int64
#
#
# freqquencyofcomplaints
# 1    150
# 0    143
# 2      7
# Name: count, dtype: int64
#
#
# Severityofcomplaints
# 0    153
# 1    115
# 2     32
# Name: count, dtype: int64
#
#
# Ocularsymptomsobservedlately
# 5    55
# 9    55
# 6    54
# 4    47
# 3    29
# 2    19
# 0    13
# 7    10
# 8     9
# 1     9
# Name: count, dtype: int64
#
#
# Symptomsobservingatleasthalfofthetimes
# 3    106
# 4     72
# 2     55
# 5     52
# 1     15
# Name: count, dtype: int64
#
#
# Complaintsfrequency
# 2    154
# 1    115
# 3     31
# Name: count, dtype: int64
#
#
# frequencyofdryeyes
# 2    163
# 3     81
# 1     56
# Name: count, dtype: int64
#
#
# Schimers1Lefteye
# 16    24
# 26    24
# 22    22
# 24    22
# 12    21
# 28    20
# 32    19
# 14    17
# 18    14
# 23    10
# 30    10
# 35     9
# 13     9
# 15     8
# 8      8
# 27     8
# 25     7
# 20     7
# 17     6
# 19     5
# 6      5
# 29     5
# 34     4
# 21     4
# 11     3
# 4      3
# 10     2
# 9      2
# 33     1
# 7      1
# Name: count, dtype: int64
#
#
# Schimers1righteye
# 28    35
# 26    22
# 24    20
# 22    18
# 30    18
# 14    15
# 12    14
# 16    13
# 18    13
# 19    12
# 10    10
# 15     9
# 23     9
# 29     9
# 21     8
# 13     8
# 17     7
# 32     7
# 25     7
# 31     6
# 27     6
# 35     6
# 8      5
# 20     5
# 34     5
# 11     4
# 4      3
# 6      2
# 2      1
# 5      1
# 7      1
# 9      1
# Name: count, dtype: int64
#
#
# Schimers2Lefteye
# 32    28
# 29    27
# 30    27
# 28    22
# 35    20
# 24    16
# 34    16
# 20    15
# 26    14
# 31    13
# 16    13
# 15    11
# 18    10
# 14     9
# 22     9
# 19     8
# 12     6
# 21     6
# 9      5
# 25     5
# 33     4
# 23     4
# 11     3
# 27     3
# 17     2
# 13     2
# 8      1
# 10     1
# Name: count, dtype: int64
#
#
# Schimers2righteye
# 32    29
# 30    28
# 28    27
# 35    23
# 26    22
# 29    21
# 31    12
# 34    12
# 25    11
# 24    11
# 19     9
# 27     9
# 22     9
# 14     9
# 20     8
# 18     8
# 23     7
# 21     7
# 12     7
# 10     5
# 16     5
# 33     4
# 15     3
# 17     3
# 11     3
# 8      3
# 7      2
# 9      1
# 6      1
# 13     1
# Name: count, dtype: int64

# %%
# Duration(3) onlineplatforms(2) Nature(2) workingyears(3) levelofgadjetwithrespecttoeyes(2) 
# Distancekeptbetweeneyesandgadjet(3) Difficultyinfocusingafterusingscreens(3) frequencyofdryeyes(3) 


#  Ocularsymptomsobservedlately and Symptomsobservingatleasthalfofthetimes


# THIS ARE THE OUTLIERS

# %%
attributes=['Sex','wearables','screenillumination','hoursspentdailycurricular','hoursspentdailynoncurricular']
plt.figure(figsize=(14, 8))
sns.boxplot(data=data[attributes], showfliers=True)
Q1 = data[attributes].quantile(0.25)
Q3 = data[attributes].quantile(0.75)
IQR = Q3 - Q1
outliers = ((data[attributes] < (Q1 - 1.5 * IQR)) | (data[attributes] > (Q3 + 1.5 * IQR)))
for i, attribute in enumerate(attributes):
    outlier_points = data.loc[outliers[attribute], attribute]
    plt.scatter(x=[i]*len(outlier_points),y=outlier_points,marker='x',color='red',s=100,label='Outliers' if i == 0 else '')
plt.show()

# %%
# hoursspentdailycurricular
# 1.0    153
# 2.0     72
# 3.0     49
# 4.0     21

# DUE TO 4.O IS LESS CHOOSEN IT IS GOT AS OUTLIER

# %%
attributes=['Complaintsfrequency','Schimers1Lefteye','Schimers1righteye','Schimers2Lefteye','Schimers2righteye']
plt.figure(figsize=(14, 8))
sns.boxplot(data=data[attributes], showfliers=True)
Q1 = data[attributes].quantile(0.25)
Q3 = data[attributes].quantile(0.75)
IQR = Q3 - Q1
outliers = ((data[attributes] < (Q1 - 1.5 * IQR)) | (data[attributes] > (Q3 + 1.5 * IQR)))
for i, attribute in enumerate(attributes):
    outlier_points = data.loc[outliers[attribute], attribute]
    plt.scatter(x=[i]*len(outlier_points),y=outlier_points,marker='x',color='red',s=100,label='Outliers' if i == 0 else '')
plt.show()

# %%
attributes=['Gadgetsused','Avgnighttimeusageperday','Blinkingduringscreenusage','freqquencyofcomplaints','Severityofcomplaints']
plt.figure(figsize=(14, 8))
sns.boxplot(data=data[attributes], showfliers=True)
Q1 = data[attributes].quantile(0.25)
Q3 = data[attributes].quantile(0.75)
IQR = Q3 - Q1
outliers = ((data[attributes] < (Q1 - 1.5 * IQR)) | (data[attributes] > (Q3 + 1.5 * IQR)))
for i, attribute in enumerate(attributes):
    outlier_points = data.loc[outliers[attribute], attribute]
    plt.scatter(x=[i]*len(outlier_points),y=outlier_points,marker='x',color='red',s=100,label='Outliers' if i == 0 else '')
plt.show()

# %%
# Gadgetsused
# 1.0    253
# 2.0     31
# 3.0     16
 
# SIMILARLY 2,3 IS ALSO LESS CHOOSEN

# %%
attributes = ['Duration', 'onlineplatforms', 'Nature', 'workingyears']
plt.figure(figsize=(14, 8))
sns.boxplot(data=data[attributes], showfliers=True)
Q1 = data[attributes].quantile(0.25)
Q3 = data[attributes].quantile(0.75)
IQR = Q3 - Q1
outliers = ((data[attributes] < (Q1 - 1.5 * IQR)) | (data[attributes] > (Q3 + 1.5 * IQR)))
for i, attribute in enumerate(attributes):
    outlier_points = data.loc[outliers[attribute], attribute]
    plt.scatter(x=[i]*len(outlier_points),y=outlier_points,marker='x',color='red',s=100,label='Outliers' if i == 0 else '')
plt.show()

# %%
attributes = ['levelofgadjetwithrespecttoeyes','Distancekeptbetweeneyesandgadjet','Difficultyinfocusingafterusingscreens',
              'frequencyofdryeyes']
plt.figure(figsize=(14, 8))
sns.boxplot(data=data[attributes], showfliers=True)
Q1 = data[attributes].quantile(0.25)
Q3 = data[attributes].quantile(0.75)
IQR = Q3 - Q1
outliers = ((data[attributes] < (Q1 - 1.5 * IQR)) | (data[attributes] > (Q3 + 1.5 * IQR)))
for i, attribute in enumerate(attributes):
    outlier_points = data.loc[outliers[attribute], attribute]
    plt.scatter(x=[i]*len(outlier_points),y=outlier_points,marker='x',color='red',s=100,label='Outliers' if i == 0 else '')
plt.show()

# %%
attributes=['Symptomsobservingatleasthalfofthetimes','Ocularsymptomsobservedlately']
plt.figure(figsize=(14, 8))
sns.boxplot(data=data[attributes], showfliers=True)
Q1 = data[attributes].quantile(0.25)
Q3 = data[attributes].quantile(0.75)
IQR = Q3 - Q1
outliers = ((data[attributes] < (Q1 - 1.5 * IQR)) | (data[attributes] > (Q3 + 1.5 * IQR)))
for i, attribute in enumerate(attributes):
    outlier_points = data.loc[outliers[attribute], attribute]
    plt.scatter(x=[i]*len(outlier_points),y=outlier_points,marker='x',color='red',s=100,label='Outliers' if i == 0 else '')
plt.show()

# %% [markdown]
# # OUTLIERS  HANDLING for Ocularsymptomsobservedlately and Symptomsobservingatleasthalfofthetimes

# %%
# Assuming 'Ocularsymptomsobservedlately' contains values of type 'object'
data['Ocularsymptomsobservedlately'] = data['Ocularsymptomsobservedlately'].astype(str)

# Function to check if the value is a single digit
def is_single_digit(x):
    return len(x) == 1 and x.isdigit()

# Function to calculate the sum of digits
def calculate_digit_sum(x):
    digits = ''.join(filter(str.isdigit, x))
    return sum(map(int, digits))

# Function to calculate the average digit value
def calculate_average_digit_value(x):
    # Check if it is a single digit
    if is_single_digit(x):
        return int(x)
    
    # Filter out non-integer values
    digits = [int(d) for d in x if d.isdigit()]
    
    # Check if there are multiple digits
    if digits:
        return round(sum(digits) / len(digits))
    else:
        return np.nan

# Iterate through the rows and print the results
for index, row in data.iterrows():
    original_value = row['Ocularsymptomsobservedlately']
    average_value = calculate_average_digit_value(original_value.split('.')[0])
    


    # Update the column with the average value
    data.at[index, 'Ocularsymptomsobservedlately'] = average_value

# %%
# Assuming you want to see all unique values in the 'Ocularsymptomsobservedlately' column
unique_values = data['Ocularsymptomsobservedlately'].unique()

# Print the unique values
print(unique_values)
# Out:
# [5 6 3 7 4 9 0 8 1 2]

# %%
data['Symptomsobservingatleasthalfofthetimes'] = data['Symptomsobservingatleasthalfofthetimes'].astype(str)

# Function to calculate the average digit value
def calculate_average_digit_value(x):
    # Check if it is a single digit
    if is_single_digit(x):
        return int(x)
    
    # Filter out non-integer values
    digits = [int(d) for d in x if d.isdigit()]
    
    # Check if there are multiple digits
    if digits:
        return round(sum(digits) / len(digits))
    else:
        return np.nan

# Calculate the average digit value and replace the original column
data['Symptomsobservingatleasthalfofthetimes'] = data['Symptomsobservingatleasthalfofthetimes'].apply(lambda x: calculate_average_digit_value(x.split('.')[0]))

# %%
# Assuming 'Symptomsobservingatleasthalfofthetimes' contains values of type 'object'
data['Symptomsobservingatleasthalfofthetimes'] = data['Symptomsobservingatleasthalfofthetimes'].astype(str)

# Function to check if the value is a single digit
def is_single_digit(x):
    return len(x) == 1 and x.isdigit()

# Function to calculate the average digit value
def calculate_average_digit_value(x):
    # Check if it is a single digit
    if is_single_digit(x):
        return int(x)
    
    # Filter out non-integer values
    digits = [int(d) for d in x if d.isdigit()]
    
    # Check if there are multiple digits
    if digits:
        return round(sum(digits) / len(digits))
    else:
        return np.nan

# Iterate over each row and print the values for each iteration
for index, row in data.iterrows():
  
    
    # Apply the function to each row
    updated_value = calculate_average_digit_value(row['Symptomsobservingatleasthalfofthetimes'].split('.')[0])
    
    
    # Update the column with the new value
    data.at[index, 'Symptomsobservingatleasthalfofthetimes'] = updated_value

# %%
# Assuming you want to see all unique values in the 'Ocularsymptomsobservedlately' column
unique_values = data['Symptomsobservingatleasthalfofthetimes'].unique()

# Print the unique values
print(unique_values)
# Out:
# [3 2 1 4 5]

# %%
attributes=['Symptomsobservingatleasthalfofthetimes','Ocularsymptomsobservedlately']
plt.figure(figsize=(14, 8))
sns.boxplot(data=data[attributes], showfliers=True)
Q1 = data[attributes].quantile(0.25)
Q3 = data[attributes].quantile(0.75)
IQR = Q3 - Q1
outliers = ((data[attributes] < (Q1 - 1.5 * IQR)) | (data[attributes] > (Q3 + 1.5 * IQR)))
for i, attribute in enumerate(attributes):
    outlier_points = data.loc[outliers[attribute], attribute]
    plt.scatter(x=[i]*len(outlier_points),y=outlier_points,marker='x',color='red',s=100,label='Outliers' if i == 0 else '')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Name                                    300 non-null    object
#  1   Age                                     300 non-null    int64
#  2   Sex                                     300 non-null    int64
#  3   wearables                               300 non-null    int64
#  4   Duration                                300 non-null    int64
#  5   onlineplatforms                         300 non-null    int64
#  6   Nature                                  300 non-null    int64
#  7   screenillumination                      300 non-null    int64
#  8   workingyears                            300 non-null    int64
#  9   hoursspentdailycurricular               300 non-null    int64
#  10  hoursspentdailynoncurricular            300 non-null    int64
#  11  Gadgetsused                             300 non-null    int64
#  12  levelofgadjetwithrespecttoeyes          300 non-null    int64
#  13  Distancekeptbetweeneyesandgadjet        300 non-null    int64
#  14  Avgnighttimeusageperday                 300 non-null    int64
#  15  Blinkingduringscreenusage               300 non-null    int64
#  16  Difficultyinfocusingafterusingscreens   300 non-null    int64
#  17  freqquencyofcomplaints                  300 non-null    int64
#  18  Severityofcomplaints                    300 non-null    int64
#  19  Ocularsymptomsobservedlately            300 non-null    object
#  20  Symptomsobservingatleasthalfofthetimes  300 non-null    object
#  21  Complaintsfrequency                     300 non-null    int64
#  22  frequencyofdryeyes                      300 non-null    int64
#  23  Schimers1Lefteye                        300 non-null    int64
#  24  Schimers1righteye                       300 non-null    int64
#  25  Schimers2Lefteye                        300 non-null    int64
#  26  Schimers2righteye                       300 non-null    int64
# dtypes: int64(24), object(3)
# memory usage: 63.4+ KB

# %% [markdown]
# # OUTLIER HANDLING FOR Duration,onlineplatforms,Nature,workingyears,levelofgadjetwithrespecttoeyes,Distancekeptbetweeneyesandgadjet,Difficultyinfocusingafterusingscreens,frequencyofdryeyes

# %%
q1 = data['Duration'].quantile(0.25)
q3 = data['Duration'].quantile(0.75)

# Step 3: Calculate IQR for the 'duration' column
iqr = q3 - q1

# Step 4: Identify potential outliers for the 'duration' column
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Print lower and upper bounds
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Step 5: Identify outliers in the 'duration' column
outliers = (data['Duration'] < lower_bound) | (data['Duration'] > upper_bound)

print("Outliers in 'duration' column:", data['Duration'][outliers])


mode_duration = data['Duration'].mode().iloc[0]  # Get the mode (first value in case of multiple modes)
data.loc[outliers, 'Duration'] = mode_duration
print("Mode of 'Duration' column:", mode_duration)
# Out:
# Lower Bound: -0.5
# Upper Bound: 3.5
# Outliers in 'duration' column: Series([], Name: Duration, dtype: int64)
# Mode of 'Duration' column: 1

# %%
for column in data.columns[2:]:
    unique_counts = data[column].value_counts()
    print(unique_counts)
    print("\n")
# Out:
# Sex
# 2    166
# 1    134
# Name: count, dtype: int64
#
#
# wearables
# 1    134
# 3     89
# 5     35
# 4     23
# 2     19
# Name: count, dtype: int64
#
#
# Duration
# 1    222
# 2     59
# 3     19
# Name: count, dtype: int64
#
#
# onlineplatforms
# 2    195
# 1    105
# Name: count, dtype: int64
#
#
# Nature
# 2    250
# 1     50
# Name: count, dtype: int64
#
#
# screenillumination
# 2    129
# 1    118
# 3     53
# Name: count, dtype: int64
#
#
# workingyears
# 1    173
# 2     84
# 3     43
# Name: count, dtype: int64
#
#
# hoursspentdailycurricular
# 1    158
# 2     72
# 3     49
# 4     21
# Name: count, dtype: int64
#
#
# hoursspentdailynoncurricular
# 2    98
# 1    91
# 3    67
# 4    44
# Name: count, dtype: int64
#
#
# Gadgetsused
# 1    253
# 2     31
# 3     16
# Name: count, dtype: int64
#
#
# levelofgadjetwithrespecttoeyes
# 2    219
# 1     81
# Name: count, dtype: int64
#
#
# Distancekeptbetweeneyesandgadjet
# 2    187
# 1     93
# 3     20
# Name: count, dtype: int64
#
#
# Avgnighttimeusageperday
# 2    121
# 1     78
# 3     73
# 4     28
# Name: count, dtype: int64
#
#
# Blinkingduringscreenusage
# 2    168
# 1    132
# Name: count, dtype: int64
#
#
# Difficultyinfocusingafterusingscreens
# 2    147
# 3     89
# 1     64
# Name: count, dtype: int64
#
#
# freqquencyofcomplaints
# 1    150
# 0    143
# 2      7
# Name: count, dtype: int64
#
#
# Severityofcomplaints
# 0    153
# 1    115
# 2     32
# Name: count, dtype: int64
#
#
# Ocularsymptomsobservedlately
# 5    55
# 9    55
# 6    54
# 4    47
# 3    29
# 2    19
# 0    13
# 7    10
# 8     9
# 1     9
# Name: count, dtype: int64
#
#
# Symptomsobservingatleasthalfofthetimes
# 3    106
# 4     72
# 2     55
# 5     52
# 1     15
# Name: count, dtype: int64
#
#
# Complaintsfrequency
# 2    154
# 1    115
# 3     31
# Name: count, dtype: int64
#
#
# frequencyofdryeyes
# 2    163
# 3     81
# 1     56
# Name: count, dtype: int64
#
#
# Schimers1Lefteye
# 16    24
# 26    24
# 22    22
# 24    22
# 12    21
# 28    20
# 32    19
# 14    17
# 18    14
# 23    10
# 30    10
# 35     9
# 13     9
# 15     8
# 8      8
# 27     8
# 25     7
# 20     7
# 17     6
# 19     5
# 6      5
# 29     5
# 34     4
# 21     4
# 11     3
# 4      3
# 10     2
# 9      2
# 33     1
# 7      1
# Name: count, dtype: int64
#
#
# Schimers1righteye
# 28    35
# 26    22
# 24    20
# 22    18
# 30    18
# 14    15
# 12    14
# 16    13
# 18    13
# 19    12
# 10    10
# 15     9
# 23     9
# 29     9
# 21     8
# 13     8
# 17     7
# 32     7
# 25     7
# 31     6
# 27     6
# 35     6
# 8      5
# 20     5
# 34     5
# 11     4
# 4      3
# 6      2
# 2      1
# 5      1
# 7      1
# 9      1
# Name: count, dtype: int64
#
#
# Schimers2Lefteye
# 32    28
# 29    27
# 30    27
# 28    22
# 35    20
# 24    16
# 34    16
# 20    15
# 26    14
# 31    13
# 16    13
# 15    11
# 18    10
# 14     9
# 22     9
# 19     8
# 12     6
# 21     6
# 9      5
# 25     5
# 33     4
# 23     4
# 11     3
# 27     3
# 17     2
# 13     2
# 8      1
# 10     1
# Name: count, dtype: int64
#
#
# Schimers2righteye
# 32    29
# 30    28
# 28    27
# 35    23
# 26    22
# 29    21
# 31    12
# 34    12
# 25    11
# 24    11
# 19     9
# 27     9
# 22     9
# 14     9
# 20     8
# 18     8
# 23     7
# 21     7
# 12     7
# 10     5
# 16     5
# 33     4
# 15     3
# 17     3
# 11     3
# 8      3
# 7      2
# 9      1
# 6      1
# 13     1
# Name: count, dtype: int64

# %%
q1 = data['onlineplatforms'].quantile(0.25)
q3 = data['onlineplatforms'].quantile(0.75)

# Step 3: Calculate IQR for the 'duration' column
iqr = q3 - q1

# Step 4: Identify potential outliers for the 'duration' column
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Print lower and upper bounds
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Step 5: Identify outliers in the 'duration' column
outliers = (data['onlineplatforms'] < lower_bound) | (data['onlineplatforms'] > upper_bound)

print("Outliers in 'onlineplatforms' column:", data['onlineplatforms'][outliers])


mode_duration = data['onlineplatforms'].mode().iloc[0]  # Get the mode (first value in case of multiple modes)
data.loc[outliers, 'onlineplatforms'] = mode_duration
print("Mode of 'onlineplatforms' column:", mode_duration)
# Out:
# Lower Bound: -0.5
# Upper Bound: 3.5
# Outliers in 'onlineplatforms' column: Series([], Name: onlineplatforms, dtype: int64)
# Mode of 'onlineplatforms' column: 2

# %%
# Identify outliers in the 'Nature' column
outliers = (data['onlineplatforms'] == 3.0)

# Print the identified outliers
print("Outliers in 'onlineplatforms' column:", data['onlineplatforms'][outliers])

# Replace outliers with the mode of the column
mode_nature = data['onlineplatforms'].mode().iloc[0]
data.loc[outliers, 'onlineplatforms'] = mode_nature
print("Mode of 'onlineplatforms' column:", mode_nature)
# Out:
# Outliers in 'onlineplatforms' column: Series([], Name: onlineplatforms, dtype: int64)
# Mode of 'onlineplatforms' column: 2

# %%
for column in data.columns[2:]:
    unique_counts = data[column].value_counts()
    print(unique_counts)
    print("\n")
# Out:
# Sex
# 2    166
# 1    134
# Name: count, dtype: int64
#
#
# wearables
# 1    134
# 3     89
# 5     35
# 4     23
# 2     19
# Name: count, dtype: int64
#
#
# Duration
# 1    222
# 2     59
# 3     19
# Name: count, dtype: int64
#
#
# onlineplatforms
# 2    195
# 1    105
# Name: count, dtype: int64
#
#
# Nature
# 2    250
# 1     50
# Name: count, dtype: int64
#
#
# screenillumination
# 2    129
# 1    118
# 3     53
# Name: count, dtype: int64
#
#
# workingyears
# 1    173
# 2     84
# 3     43
# Name: count, dtype: int64
#
#
# hoursspentdailycurricular
# 1    158
# 2     72
# 3     49
# 4     21
# Name: count, dtype: int64
#
#
# hoursspentdailynoncurricular
# 2    98
# 1    91
# 3    67
# 4    44
# Name: count, dtype: int64
#
#
# Gadgetsused
# 1    253
# 2     31
# 3     16
# Name: count, dtype: int64
#
#
# levelofgadjetwithrespecttoeyes
# 2    219
# 1     81
# Name: count, dtype: int64
#
#
# Distancekeptbetweeneyesandgadjet
# 2    187
# 1     93
# 3     20
# Name: count, dtype: int64
#
#
# Avgnighttimeusageperday
# 2    121
# 1     78
# 3     73
# 4     28
# Name: count, dtype: int64
#
#
# Blinkingduringscreenusage
# 2    168
# 1    132
# Name: count, dtype: int64
#
#
# Difficultyinfocusingafterusingscreens
# 2    147
# 3     89
# 1     64
# Name: count, dtype: int64
#
#
# freqquencyofcomplaints
# 1    150
# 0    143
# 2      7
# Name: count, dtype: int64
#
#
# Severityofcomplaints
# 0    153
# 1    115
# 2     32
# Name: count, dtype: int64
#
#
# Ocularsymptomsobservedlately
# 5    55
# 9    55
# 6    54
# 4    47
# 3    29
# 2    19
# 0    13
# 7    10
# 8     9
# 1     9
# Name: count, dtype: int64
#
#
# Symptomsobservingatleasthalfofthetimes
# 3    106
# 4     72
# 2     55
# 5     52
# 1     15
# Name: count, dtype: int64
#
#
# Complaintsfrequency
# 2    154
# 1    115
# 3     31
# Name: count, dtype: int64
#
#
# frequencyofdryeyes
# 2    163
# 3     81
# 1     56
# Name: count, dtype: int64
#
#
# Schimers1Lefteye
# 16    24
# 26    24
# 22    22
# 24    22
# 12    21
# 28    20
# 32    19
# 14    17
# 18    14
# 23    10
# 30    10
# 35     9
# 13     9
# 15     8
# 8      8
# 27     8
# 25     7
# 20     7
# 17     6
# 19     5
# 6      5
# 29     5
# 34     4
# 21     4
# 11     3
# 4      3
# 10     2
# 9      2
# 33     1
# 7      1
# Name: count, dtype: int64
#
#
# Schimers1righteye
# 28    35
# 26    22
# 24    20
# 22    18
# 30    18
# 14    15
# 12    14
# 16    13
# 18    13
# 19    12
# 10    10
# 15     9
# 23     9
# 29     9
# 21     8
# 13     8
# 17     7
# 32     7
# 25     7
# 31     6
# 27     6
# 35     6
# 8      5
# 20     5
# 34     5
# 11     4
# 4      3
# 6      2
# 2      1
# 5      1
# 7      1
# 9      1
# Name: count, dtype: int64
#
#
# Schimers2Lefteye
# 32    28
# 29    27
# 30    27
# 28    22
# 35    20
# 24    16
# 34    16
# 20    15
# 26    14
# 31    13
# 16    13
# 15    11
# 18    10
# 14     9
# 22     9
# 19     8
# 12     6
# 21     6
# 9      5
# 25     5
# 33     4
# 23     4
# 11     3
# 27     3
# 17     2
# 13     2
# 8      1
# 10     1
# Name: count, dtype: int64
#
#
# Schimers2righteye
# 32    29
# 30    28
# 28    27
# 35    23
# 26    22
# 29    21
# 31    12
# 34    12
# 25    11
# 24    11
# 19     9
# 27     9
# 22     9
# 14     9
# 20     8
# 18     8
# 23     7
# 21     7
# 12     7
# 10     5
# 16     5
# 33     4
# 15     3
# 17     3
# 11     3
# 8      3
# 7      2
# 9      1
# 6      1
# 13     1
# Name: count, dtype: int64

# %%
q1 = data['workingyears'].quantile(0.25)
q3 = data['workingyears'].quantile(0.75)

# Step 3: Calculate IQR for the 'duration' column
iqr = q3 - q1

# Step 4: Identify potential outliers for the 'duration' column
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Print lower and upper bounds
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Step 5: Identify outliers in the 'duration' column
outliers = (data['workingyears'] < lower_bound) | (data['workingyears'] > upper_bound)

print("Outliers in 'workingyears' column:", data['workingyears'][outliers])


mode_duration = data['workingyears'].mode().iloc[0]  # Get the mode (first value in case of multiple modes)
data.loc[outliers, 'workingyears'] = mode_duration
print("Mode of 'workingyears' column:", mode_duration)
# Out:
# Lower Bound: -0.5
# Upper Bound: 3.5
# Outliers in 'workingyears' column: Series([], Name: workingyears, dtype: int64)
# Mode of 'workingyears' column: 1

# %%
q1 = data['Distancekeptbetweeneyesandgadjet'].quantile(0.25)
q3 = data['Distancekeptbetweeneyesandgadjet'].quantile(0.75)

# Step 3: Calculate IQR for the 'duration' column
iqr = q3 - q1

# Step 4: Identify potential outliers for the 'duration' column
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Print lower and upper bounds
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Step 5: Identify outliers in the 'duration' column
outliers = (data['Distancekeptbetweeneyesandgadjet'] < lower_bound) | (data['Distancekeptbetweeneyesandgadjet'] > upper_bound)

print("Outliers in 'Distancekeptbetweeneyesandgadjet' column:", data['Distancekeptbetweeneyesandgadjet'][outliers])


mode_duration = data['Distancekeptbetweeneyesandgadjet'].mode().iloc[0]  # Get the mode (first value in case of multiple modes)
data.loc[outliers, 'Distancekeptbetweeneyesandgadjet'] = mode_duration
print("Mode of 'Distancekeptbetweeneyesandgadjet' column:", mode_duration)
# Out:
# Lower Bound: -0.5
# Upper Bound: 3.5
# Outliers in 'Distancekeptbetweeneyesandgadjet' column: Series([], Name: Distancekeptbetweeneyesandgadjet, dtype: int64)
# Mode of 'Distancekeptbetweeneyesandgadjet' column: 2

# %%
q1 = data['Difficultyinfocusingafterusingscreens'].quantile(0.25)
q3 = data['Difficultyinfocusingafterusingscreens'].quantile(0.75)

# Step 3: Calculate IQR for the 'duration' column
iqr = q3 - q1

# Step 4: Identify potential outliers for the 'duration' column
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Print lower and upper bounds
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Step 5: Identify outliers in the 'duration' column
outliers = (data['Difficultyinfocusingafterusingscreens'] < lower_bound) | (data['Difficultyinfocusingafterusingscreens'] > upper_bound)

print("Outliers in 'Difficultyinfocusingafterusingscreens' column:", data['Duration'][outliers])


mode_duration = data['Difficultyinfocusingafterusingscreens'].mode().iloc[0]  # Get the mode (first value in case of multiple modes)
data.loc[outliers, 'Difficultyinfocusingafterusingscreens'] = mode_duration
print("Mode of 'Difficultyinfocusingafterusingscreens' column:", mode_duration)
# Out:
# Lower Bound: 0.5
# Upper Bound: 4.5
# Outliers in 'Difficultyinfocusingafterusingscreens' column: Series([], Name: Duration, dtype: int64)
# Mode of 'Difficultyinfocusingafterusingscreens' column: 2

# %%
q1 = data['frequencyofdryeyes'].quantile(0.25)
q3 = data['frequencyofdryeyes'].quantile(0.75)

# Step 3: Calculate IQR for the 'duration' column
iqr = q3 - q1

# Step 4: Identify potential outliers for the 'duration' column
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Print lower and upper bounds
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Step 5: Identify outliers in the 'duration' column
outliers = (data['frequencyofdryeyes'] < lower_bound) | (data['frequencyofdryeyes'] > upper_bound)

print("Outliers in 'frequencyofdryeyes' column:", data['frequencyofdryeyes'][outliers])


mode_duration = data['frequencyofdryeyes'].mode().iloc[0]  # Get the mode (first value in case of multiple modes)
data.loc[outliers, 'frequencyofdryeyes'] = mode_duration
print("Mode of 'frequencyofdryeyes' column:", mode_duration)
# Out:
# Lower Bound: 0.5
# Upper Bound: 4.5
# Outliers in 'frequencyofdryeyes' column: Series([], Name: frequencyofdryeyes, dtype: int64)
# Mode of 'frequencyofdryeyes' column: 2

# %%
q1 = data['RVIS'].quantile(0.25)
q3 = data['RVIS'].quantile(0.75)

# Step 3: Calculate IQR for the 'duration' column
iqr = q3 - q1

# Step 4: Identify potential outliers for the 'duration' column
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Print lower and upper bounds
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Step 5: Identify outliers in the 'duration' column
outliers = (data['RVIS'] < lower_bound) | (data['RVIS'] > upper_bound)

print("Outliers in 'RVIS' column:", data['RVIS'][outliers])


mode_duration = data['RVIS'].mode().iloc[0]  # Get the mode (first value in case of multiple modes)
data.loc[outliers, 'RVIS'] = mode_duration
print("Mode of 'RVIS' column:", mode_duration)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RVIS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 q1 = data['RVIS'].quantile(0.25)
#       2 q3 = data['RVIS'].quantile(0.75)
#       4 # Step 3: Calculate IQR for the 'duration' column
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'RVIS'

# %%
# Identify outliers in the 'Nature' column
outliers = (data['Nature'] == 3.0) | (data['Nature'] == 12.0)

# Print the identified outliers
print("Outliers in 'Nature' column:", data['Nature'][outliers])

# Replace outliers with the mode of the column
mode_nature = data['Nature'].mode().iloc[0]
data.loc[outliers, 'Nature'] = mode_nature
print("Mode of 'Nature' column:", mode_nature)
# Out:
# Outliers in 'Nature' column: Series([], Name: Nature, dtype: int64)
# Mode of 'Nature' column: 2

# %%
from scipy.stats import zscore

# Calculate Z-scores for the 'levelofgadjetwithrespecttoeyes' column
z_scores = zscore(data['levelofgadjetwithrespecttoeyes'])

# Set a threshold for Z-score (e.g., 3.0)
threshold = 3.0

# Identify outliers based on the Z-score
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Print the identified outliers
print("Outliers in 'levelofgadjetwithrespecttoeyes' column:", data['levelofgadjetwithrespecttoeyes'][outliers])

# Replace outliers with the mode of the column
mode_duration = data['levelofgadjetwithrespecttoeyes'].mode().iloc[0]
data.loc[outliers, 'levelofgadjetwithrespecttoeyes'] = mode_duration
print("Mode of 'levelofgadjetwithrespecttoeyes' column:", mode_duration)

# Identify outliers in the 'levelofgadjetwithrespecttoeyes' column
outliers = (data['levelofgadjetwithrespecttoeyes'] == 3.0)

# Print the identified outliers
print("Outliers in 'levelofgadjetwithrespecttoeyes' column:", data['levelofgadjetwithrespecttoeyes'][outliers])

# Replace outliers with the mode of the column
mode_duration = data['levelofgadjetwithrespecttoeyes'].mode().iloc[0]
data.loc[outliers, 'levelofgadjetwithrespecttoeyes'] = mode_duration
print("Mode of 'levelofgadjetwithrespecttoeyes' column:", mode_duration)
# Out:
# Outliers in 'levelofgadjetwithrespecttoeyes' column: Series([], Name: levelofgadjetwithrespecttoeyes, dtype: int64)
# Mode of 'levelofgadjetwithrespecttoeyes' column: 2
# Outliers in 'levelofgadjetwithrespecttoeyes' column: Series([], Name: levelofgadjetwithrespecttoeyes, dtype: int64)
# Mode of 'levelofgadjetwithrespecttoeyes' column: 2

# %%
for column in data.columns[2:]:
    unique_counts = data[column].value_counts()
    print(unique_counts)
    print("\n")
# Out:
# Sex
# 2    166
# 1    134
# Name: count, dtype: int64
#
#
# wearables
# 1    134
# 3     89
# 5     35
# 4     23
# 2     19
# Name: count, dtype: int64
#
#
# Duration
# 1    222
# 2     59
# 3     19
# Name: count, dtype: int64
#
#
# onlineplatforms
# 2    195
# 1    105
# Name: count, dtype: int64
#
#
# Nature
# 2    250
# 1     50
# Name: count, dtype: int64
#
#
# screenillumination
# 2    129
# 1    118
# 3     53
# Name: count, dtype: int64
#
#
# workingyears
# 1    173
# 2     84
# 3     43
# Name: count, dtype: int64
#
#
# hoursspentdailycurricular
# 1    158
# 2     72
# 3     49
# 4     21
# Name: count, dtype: int64
#
#
# hoursspentdailynoncurricular
# 2    98
# 1    91
# 3    67
# 4    44
# Name: count, dtype: int64
#
#
# Gadgetsused
# 1    253
# 2     31
# 3     16
# Name: count, dtype: int64
#
#
# levelofgadjetwithrespecttoeyes
# 2    219
# 1     81
# Name: count, dtype: int64
#
#
# Distancekeptbetweeneyesandgadjet
# 2    187
# 1     93
# 3     20
# Name: count, dtype: int64
#
#
# Avgnighttimeusageperday
# 2    121
# 1     78
# 3     73
# 4     28
# Name: count, dtype: int64
#
#
# Blinkingduringscreenusage
# 2    168
# 1    132
# Name: count, dtype: int64
#
#
# Difficultyinfocusingafterusingscreens
# 2    147
# 3     89
# 1     64
# Name: count, dtype: int64
#
#
# freqquencyofcomplaints
# 1    150
# 0    143
# 2      7
# Name: count, dtype: int64
#
#
# Severityofcomplaints
# 0    153
# 1    115
# 2     32
# Name: count, dtype: int64
#
#
# Ocularsymptomsobservedlately
# 5    55
# 9    55
# 6    54
# 4    47
# 3    29
# 2    19
# 0    13
# 7    10
# 8     9
# 1     9
# Name: count, dtype: int64
#
#
# Symptomsobservingatleasthalfofthetimes
# 3    106
# 4     72
# 2     55
# 5     52
# 1     15
# Name: count, dtype: int64
#
#
# Complaintsfrequency
# 2    154
# 1    115
# 3     31
# Name: count, dtype: int64
#
#
# frequencyofdryeyes
# 2    163
# 3     81
# 1     56
# Name: count, dtype: int64
#
#
# Schimers1Lefteye
# 16    24
# 26    24
# 22    22
# 24    22
# 12    21
# 28    20
# 32    19
# 14    17
# 18    14
# 23    10
# 30    10
# 35     9
# 13     9
# 15     8
# 8      8
# 27     8
# 25     7
# 20     7
# 17     6
# 19     5
# 6      5
# 29     5
# 34     4
# 21     4
# 11     3
# 4      3
# 10     2
# 9      2
# 33     1
# 7      1
# Name: count, dtype: int64
#
#
# Schimers1righteye
# 28    35
# 26    22
# 24    20
# 22    18
# 30    18
# 14    15
# 12    14
# 16    13
# 18    13
# 19    12
# 10    10
# 15     9
# 23     9
# 29     9
# 21     8
# 13     8
# 17     7
# 32     7
# 25     7
# 31     6
# 27     6
# 35     6
# 8      5
# 20     5
# 34     5
# 11     4
# 4      3
# 6      2
# 2      1
# 5      1
# 7      1
# 9      1
# Name: count, dtype: int64
#
#
# Schimers2Lefteye
# 32    28
# 29    27
# 30    27
# 28    22
# 35    20
# 24    16
# 34    16
# 20    15
# 26    14
# 31    13
# 16    13
# 15    11
# 18    10
# 14     9
# 22     9
# 19     8
# 12     6
# 21     6
# 9      5
# 25     5
# 33     4
# 23     4
# 11     3
# 27     3
# 17     2
# 13     2
# 8      1
# 10     1
# Name: count, dtype: int64
#
#
# Schimers2righteye
# 32    29
# 30    28
# 28    27
# 35    23
# 26    22
# 29    21
# 31    12
# 34    12
# 25    11
# 24    11
# 19     9
# 27     9
# 22     9
# 14     9
# 20     8
# 18     8
# 23     7
# 21     7
# 12     7
# 10     5
# 16     5
# 33     4
# 15     3
# 17     3
# 11     3
# 8      3
# 7      2
# 9      1
# 6      1
# 13     1
# Name: count, dtype: int64

# %%
attributes=['Duration','onlineplatforms','workingyears','Distancekeptbetweeneyesandgadjet','frequencyofdryeyes','levelofgadjetwithrespecttoeyes']
plt.figure(figsize=(14, 8))
sns.boxplot(data=data[attributes], showfliers=True)
Q1 = data[attributes].quantile(0.25)
Q3 = data[attributes].quantile(0.75)
IQR = Q3 - Q1
outliers = ((data[attributes] < (Q1 - 1.5 * IQR)) | (data[attributes] > (Q3 + 1.5 * IQR)))
for i, attribute in enumerate(attributes):
    outlier_points = data.loc[outliers[attribute], attribute]
    plt.scatter(x=[i]*len(outlier_points),y=outlier_points,marker='x',color='red',s=100,label='Outliers' if i == 0 else '')
plt.show()

# %%
attributes=['Duration','onlineplatforms','workingyears','Distancekeptbetweeneyesandgadjet','frequencyofdryeyes','levelofgadjetwithrespecttoeyes']
plt.figure(figsize=(14, 8))
sns.boxplot(data=data[attributes], showfliers=True)
Q1 = data[attributes].quantile(0.25)
Q3 = data[attributes].quantile(0.75)
IQR = Q3 - Q1
outliers = ((data[attributes] < (Q1 - 1.5 * IQR)) | (data[attributes] > (Q3 + 1.5 * IQR)))
for i, attribute in enumerate(attributes):
    outlier_points = data.loc[outliers[attribute], attribute]
    plt.scatter(x=[i]*len(outlier_points),y=outlier_points,marker='x',color='red',s=100,label='Outliers' if i == 0 else '')
plt.show()

# %%
attributes=['Nature','levelofgadjetwithrespecttoeyes']
plt.figure(figsize=(14, 8))
sns.boxplot(data=data[attributes], showfliers=True)
Q1 = data[attributes].quantile(0.25)
Q3 = data[attributes].quantile(0.75)
IQR = Q3 - Q1
outliers = ((data[attributes] < (Q1 - 1.5 * IQR)) | (data[attributes] > (Q3 + 1.5 * IQR)))
for i, attribute in enumerate(attributes):
    outlier_points = data.loc[outliers[attribute], attribute]
    plt.scatter(x=[i]*len(outlier_points),y=outlier_points,marker='x',color='red',s=100,label='Outliers' if i == 0 else '')
plt.show()

# %%
for column in data.columns[2:]:
    unique_counts = data[column].value_counts()
    print(unique_counts)
    print("\n")
# Out:
# Sex
# 2    166
# 1    134
# Name: count, dtype: int64
#
#
# wearables
# 1    134
# 3     89
# 5     35
# 4     23
# 2     19
# Name: count, dtype: int64
#
#
# Duration
# 1    222
# 2     59
# 3     19
# Name: count, dtype: int64
#
#
# onlineplatforms
# 2    195
# 1    105
# Name: count, dtype: int64
#
#
# Nature
# 2    250
# 1     50
# Name: count, dtype: int64
#
#
# screenillumination
# 2    129
# 1    118
# 3     53
# Name: count, dtype: int64
#
#
# workingyears
# 1    173
# 2     84
# 3     43
# Name: count, dtype: int64
#
#
# hoursspentdailycurricular
# 1    158
# 2     72
# 3     49
# 4     21
# Name: count, dtype: int64
#
#
# hoursspentdailynoncurricular
# 2    98
# 1    91
# 3    67
# 4    44
# Name: count, dtype: int64
#
#
# Gadgetsused
# 1    253
# 2     31
# 3     16
# Name: count, dtype: int64
#
#
# levelofgadjetwithrespecttoeyes
# 2    219
# 1     81
# Name: count, dtype: int64
#
#
# Distancekeptbetweeneyesandgadjet
# 2    187
# 1     93
# 3     20
# Name: count, dtype: int64
#
#
# Avgnighttimeusageperday
# 2    121
# 1     78
# 3     73
# 4     28
# Name: count, dtype: int64
#
#
# Blinkingduringscreenusage
# 2    168
# 1    132
# Name: count, dtype: int64
#
#
# Difficultyinfocusingafterusingscreens
# 2    147
# 3     89
# 1     64
# Name: count, dtype: int64
#
#
# freqquencyofcomplaints
# 1    150
# 0    143
# 2      7
# Name: count, dtype: int64
#
#
# Severityofcomplaints
# 0    153
# 1    115
# 2     32
# Name: count, dtype: int64
#
#
# Ocularsymptomsobservedlately
# 5    55
# 9    55
# 6    54
# 4    47
# 3    29
# 2    19
# 0    13
# 7    10
# 8     9
# 1     9
# Name: count, dtype: int64
#
#
# Symptomsobservingatleasthalfofthetimes
# 3    106
# 4     72
# 2     55
# 5     52
# 1     15
# Name: count, dtype: int64
#
#
# Complaintsfrequency
# 2    154
# 1    115
# 3     31
# Name: count, dtype: int64
#
#
# frequencyofdryeyes
# 2    163
# 3     81
# 1     56
# Name: count, dtype: int64
#
#
# Schimers1Lefteye
# 16    24
# 26    24
# 22    22
# 24    22
# 12    21
# 28    20
# 32    19
# 14    17
# 18    14
# 23    10
# 30    10
# 35     9
# 13     9
# 15     8
# 8      8
# 27     8
# 25     7
# 20     7
# 17     6
# 19     5
# 6      5
# 29     5
# 34     4
# 21     4
# 11     3
# 4      3
# 10     2
# 9      2
# 33     1
# 7      1
# Name: count, dtype: int64
#
#
# Schimers1righteye
# 28    35
# 26    22
# 24    20
# 22    18
# 30    18
# 14    15
# 12    14
# 16    13
# 18    13
# 19    12
# 10    10
# 15     9
# 23     9
# 29     9
# 21     8
# 13     8
# 17     7
# 32     7
# 25     7
# 31     6
# 27     6
# 35     6
# 8      5
# 20     5
# 34     5
# 11     4
# 4      3
# 6      2
# 2      1
# 5      1
# 7      1
# 9      1
# Name: count, dtype: int64
#
#
# Schimers2Lefteye
# 32    28
# 29    27
# 30    27
# 28    22
# 35    20
# 24    16
# 34    16
# 20    15
# 26    14
# 31    13
# 16    13
# 15    11
# 18    10
# 14     9
# 22     9
# 19     8
# 12     6
# 21     6
# 9      5
# 25     5
# 33     4
# 23     4
# 11     3
# 27     3
# 17     2
# 13     2
# 8      1
# 10     1
# Name: count, dtype: int64
#
#
# Schimers2righteye
# 32    29
# 30    28
# 28    27
# 35    23
# 26    22
# 29    21
# 31    12
# 34    12
# 25    11
# 24    11
# 19     9
# 27     9
# 22     9
# 14     9
# 20     8
# 18     8
# 23     7
# 21     7
# 12     7
# 10     5
# 16     5
# 33     4
# 15     3
# 17     3
# 11     3
# 8      3
# 7      2
# 9      1
# 6      1
# 13     1
# Name: count, dtype: int64

# %% [markdown]
# # NULL VALUES HANDLING

# %% [markdown]
# # Imputation

# %%
for column in data.columns[1:]:
    # Replace NaN values with the mean
    data[column].fillna(data[column].mean(), inplace=True)

    # Convert the column to integer
    data[column] = data[column].astype(int)

# Check the data types after conversion
print(data.dtypes)
# Out:
# Name                                      object
# Age                                        int32
# Sex                                        int32
# wearables                                  int32
# Duration                                   int32
# onlineplatforms                            int32
# Nature                                     int32
# screenillumination                         int32
# workingyears                               int32
# hoursspentdailycurricular                  int32
# hoursspentdailynoncurricular               int32
# Gadgetsused                                int32
# levelofgadjetwithrespecttoeyes             int32
# Distancekeptbetweeneyesandgadjet           int32
# Avgnighttimeusageperday                    int32
# Blinkingduringscreenusage                  int32
# Difficultyinfocusingafterusingscreens      int32
# freqquencyofcomplaints                     int32
# Severityofcomplaints                       int32
# Ocularsymptomsobservedlately               int32
# Symptomsobservingatleasthalfofthetimes     int32
# Complaintsfrequency                        int32
# frequencyofdryeyes                         int32
# Schimers1Lefteye                           int32
# Schimers1righteye                          int32
# Schimers2Lefteye                           int32
# Schimers2righteye                          int32
# dtype: object
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# C:\Users\cialg\AppData\Local\Temp\ipykernel_13396\919842512.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)

# %%
data.isnull().sum()
# Out:
# Name                                      0
# Age                                       0
# Sex                                       0
# wearables                                 0
# Duration                                  0
# onlineplatforms                           0
# Nature                                    0
# screenillumination                        0
# workingyears                              0
# hoursspentdailycurricular                 0
# hoursspentdailynoncurricular              0
# Gadgetsused                               0
# levelofgadjetwithrespecttoeyes            0
# Distancekeptbetweeneyesandgadjet          0
# Avgnighttimeusageperday                   0
# Blinkingduringscreenusage                 0
# Difficultyinfocusingafterusingscreens     0
# freqquencyofcomplaints                    0
# Severityofcomplaints                      0
# Ocularsymptomsobservedlately              0
# Symptomsobservingatleasthalfofthetimes    0
# Complaintsfrequency                       0
# frequencyofdryeyes                        0
# Schimers1Lefteye                          0
# Schimers1righteye                         0
# Schimers2Lefteye                          0
# Schimers2righteye                         0
# dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.isnull(),cmap='viridis')
plt.show()

# %%
for column in data.columns[2:]:
    unique_counts = data[column].value_counts()
    print(unique_counts)
    print("\n")
# Out:
# Sex
# 2    166
# 1    134
# Name: count, dtype: int64
#
#
# wearables
# 1    134
# 3     89
# 5     35
# 4     23
# 2     19
# Name: count, dtype: int64
#
#
# Duration
# 1    222
# 2     59
# 3     19
# Name: count, dtype: int64
#
#
# onlineplatforms
# 2    195
# 1    105
# Name: count, dtype: int64
#
#
# Nature
# 2    250
# 1     50
# Name: count, dtype: int64
#
#
# screenillumination
# 2    129
# 1    118
# 3     53
# Name: count, dtype: int64
#
#
# workingyears
# 1    173
# 2     84
# 3     43
# Name: count, dtype: int64
#
#
# hoursspentdailycurricular
# 1    158
# 2     72
# 3     49
# 4     21
# Name: count, dtype: int64
#
#
# hoursspentdailynoncurricular
# 2    98
# 1    91
# 3    67
# 4    44
# Name: count, dtype: int64
#
#
# Gadgetsused
# 1    253
# 2     31
# 3     16
# Name: count, dtype: int64
#
#
# levelofgadjetwithrespecttoeyes
# 2    219
# 1     81
# Name: count, dtype: int64
#
#
# Distancekeptbetweeneyesandgadjet
# 2    187
# 1     93
# 3     20
# Name: count, dtype: int64
#
#
# Avgnighttimeusageperday
# 2    121
# 1     78
# 3     73
# 4     28
# Name: count, dtype: int64
#
#
# Blinkingduringscreenusage
# 2    168
# 1    132
# Name: count, dtype: int64
#
#
# Difficultyinfocusingafterusingscreens
# 2    147
# 3     89
# 1     64
# Name: count, dtype: int64
#
#
# freqquencyofcomplaints
# 1    150
# 0    143
# 2      7
# Name: count, dtype: int64
#
#
# Severityofcomplaints
# 0    153
# 1    115
# 2     32
# Name: count, dtype: int64
#
#
# Ocularsymptomsobservedlately
# 5    55
# 9    55
# 6    54
# 4    47
# 3    29
# 2    19
# 0    13
# 7    10
# 8     9
# 1     9
# Name: count, dtype: int64
#
#
# Symptomsobservingatleasthalfofthetimes
# 3    106
# 4     72
# 2     55
# 5     52
# 1     15
# Name: count, dtype: int64
#
#
# Complaintsfrequency
# 2    154
# 1    115
# 3     31
# Name: count, dtype: int64
#
#
# frequencyofdryeyes
# 2    163
# 3     81
# 1     56
# Name: count, dtype: int64
#
#
# Schimers1Lefteye
# 16    24
# 26    24
# 22    22
# 24    22
# 12    21
# 28    20
# 32    19
# 14    17
# 18    14
# 23    10
# 30    10
# 35     9
# 13     9
# 15     8
# 8      8
# 27     8
# 25     7
# 20     7
# 17     6
# 19     5
# 6      5
# 29     5
# 34     4
# 21     4
# 11     3
# 4      3
# 10     2
# 9      2
# 33     1
# 7      1
# Name: count, dtype: int64
#
#
# Schimers1righteye
# 28    35
# 26    22
# 24    20
# 22    18
# 30    18
# 14    15
# 12    14
# 16    13
# 18    13
# 19    12
# 10    10
# 15     9
# 23     9
# 29     9
# 21     8
# 13     8
# 17     7
# 32     7
# 25     7
# 31     6
# 27     6
# 35     6
# 8      5
# 20     5
# 34     5
# 11     4
# 4      3
# 6      2
# 2      1
# 5      1
# 7      1
# 9      1
# Name: count, dtype: int64
#
#
# Schimers2Lefteye
# 32    28
# 29    27
# 30    27
# 28    22
# 35    20
# 24    16
# 34    16
# 20    15
# 26    14
# 31    13
# 16    13
# 15    11
# 18    10
# 14     9
# 22     9
# 19     8
# 12     6
# 21     6
# 9      5
# 25     5
# 33     4
# 23     4
# 11     3
# 27     3
# 17     2
# 13     2
# 8      1
# 10     1
# Name: count, dtype: int64
#
#
# Schimers2righteye
# 32    29
# 30    28
# 28    27
# 35    23
# 26    22
# 29    21
# 31    12
# 34    12
# 25    11
# 24    11
# 19     9
# 27     9
# 22     9
# 14     9
# 20     8
# 18     8
# 23     7
# 21     7
# 12     7
# 10     5
# 16     5
# 33     4
# 15     3
# 17     3
# 11     3
# 8      3
# 7      2
# 9      1
# 6      1
# 13     1
# Name: count, dtype: int64

# %%
# Assuming you want to see all unique values in the 'Ocularsymptomsobservedlately' column
unique_values = data['Symptomsobservingatleasthalfofthetimes'].unique()

# Print the unique values
print(unique_values)
# Out:
# [3 2 1 4 5]

# %%
# Assuming you want to see all unique values in the 'Ocularsymptomsobservedlately' column
unique_values = data['Ocularsymptomsobservedlately'].unique()

# Print the unique values
print(unique_values)
# Out:
# [5 6 3 7 4 9 0 8 1 2]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Name                                    300 non-null    object
#  1   Age                                     300 non-null    int32
#  2   Sex                                     300 non-null    int32
#  3   wearables                               300 non-null    int32
#  4   Duration                                300 non-null    int32
#  5   onlineplatforms                         300 non-null    int32
#  6   Nature                                  300 non-null    int32
#  7   screenillumination                      300 non-null    int32
#  8   workingyears                            300 non-null    int32
#  9   hoursspentdailycurricular               300 non-null    int32
#  10  hoursspentdailynoncurricular            300 non-null    int32
#  11  Gadgetsused                             300 non-null    int32
#  12  levelofgadjetwithrespecttoeyes          300 non-null    int32
#  13  Distancekeptbetweeneyesandgadjet        300 non-null    int32
#  14  Avgnighttimeusageperday                 300 non-null    int32
#  15  Blinkingduringscreenusage               300 non-null    int32
#  16  Difficultyinfocusingafterusingscreens   300 non-null    int32
#  17  freqquencyofcomplaints                  300 non-null    int32
#  18  Severityofcomplaints                    300 non-null    int32
#  19  Ocularsymptomsobservedlately            300 non-null    int32
#  20  Symptomsobservingatleasthalfofthetimes  300 non-null    int32
#  21  Complaintsfrequency                     300 non-null    int32
#  22  frequencyofdryeyes                      300 non-null    int32
#  23  Schimers1Lefteye                        300 non-null    int32
#  24  Schimers1righteye                       300 non-null    int32
#  25  Schimers2Lefteye                        300 non-null    int32
#  26  Schimers2righteye                       300 non-null    int32
# dtypes: int32(26), object(1)
# memory usage: 32.9+ KB

# %%
data.describe()
# Out:
#               Age         Sex   wearables    Duration  onlineplatforms  \
# count  300.000000  300.000000  300.000000  300.000000       300.000000
# mean    22.173333    1.553333    2.353333    1.323333         1.650000
# std      2.774096    0.497978    1.407750    0.588737         0.477767
# min     17.000000    1.000000    1.000000    1.000000         1.000000
# 25%     20.000000    1.000000    1.000000    1.000000         1.000000
# 50%     22.000000    2.000000    2.000000    1.000000         2.000000
# 75%     24.000000    2.000000    3.000000    2.000000         2.000000
# max     28.000000    2.000000    5.000000    3.000000         2.000000
#
#            Nature  screenillumination  workingyears  \
# count  300.000000          300.000000    300.000000
# mean     1.833333            1.783333      1.566667
# std      0.373301            0.724434      0.730755
# min      1.000000            1.000000      1.000000
# 25%      2.000000            1.000000      1.000000
# 50%      2.000000            2.000000      1.000000
# 75%      2.000000            2.000000      2.000000
# max      2.000000            3.000000      3.000000
#
#        hoursspentdailycurricular  hoursspentdailynoncurricular  ...  \
# count                 300.000000                    300.000000  ...
# mean                    1.776667                      2.213333  ...
# std                     0.960833                      1.035081  ...
# min                     1.000000                      1.000000  ...
# 25%                     1.000000                      1.000000  ...
# 50%                     1.000000                      2.000000  ...
# 75%                     2.000000                      3.000000  ...
# max                     4.000000                      4.000000  ...
#
#        freqquencyofcomplaints  Severityofcomplaints  \
# count              300.000000            300.000000
# mean                 0.546667              0.596667
# std                  0.543575              0.674913
# min                  0.000000              0.000000
# 25%                  0.000000              0.000000
# 50%                  1.000000              0.000000
# 75%                  1.000000              1.000000
# max                  2.000000              2.000000
#
#        Ocularsymptomsobservedlately  Symptomsobservingatleasthalfofthetimes  \
# count                    300.000000                              300.000000
# mean                       5.193333                                3.303333
# std                        2.485265                                1.108491
# min                        0.000000                                1.000000
# 25%                        4.000000                                3.000000
# 50%                        5.000000                                3.000000
# 75%                        6.000000                                4.000000
# max                        9.000000                                5.000000
#
#        Complaintsfrequency  frequencyofdryeyes  Schimers1Lefteye  \
# count           300.000000          300.000000        300.000000
# mean              1.720000            2.083333         21.073333
# std               0.640025            0.671734          7.511059
# min               1.000000            1.000000          4.000000
# 25%               1.000000            2.000000         15.000000
# 50%               2.000000            2.000000         22.000000
# 75%               2.000000            3.000000         27.000000
# max               3.000000            3.000000         35.000000
#
#        Schimers1righteye  Schimers2Lefteye  Schimers2righteye
# count         300.000000        300.000000         300.000000
# mean           21.560000         25.376667          25.733333
# std             7.377975          7.105614           7.050384
# min             2.000000          8.000000           6.000000
# 25%            16.000000         20.000000          21.750000
# 50%            22.500000         28.000000          28.000000
# 75%            28.000000         31.000000          31.000000
# max            35.000000         35.000000          35.000000
#
# [8 rows x 26 columns]

# %%
data['Test1'] = data[['Schimers1Lefteye', 'Schimers1righteye']].mean(axis=1)
print(data[['Schimers1Lefteye', 'Schimers1righteye','Test1']])
# Out:
#      Schimers1Lefteye  Schimers1righteye  Test1
# 0                  12                 13   12.5
# 1                  25                 28   26.5
# 2                   8                  6    7.0
# 3                  13                 14   13.5
# 4                  34                 32   33.0
# ..                ...                ...    ...
# 295                23                 26   24.5
# 296                26                 22   24.0
# 297                23                 27   25.0
# 298                12                 14   13.0
# 299                16                 19   17.5
#
# [300 rows x 3 columns]

# %%
data['Test2'] = data[['Schimers2Lefteye', 'Schimers2righteye']].mean(axis=1)
print(data[['Schimers2Lefteye', 'Schimers2righteye','Test2']])
# Out:
#      Schimers2Lefteye  Schimers2righteye  Test2
# 0                  16                 14   15.0
# 1                  30                 32   31.0
# 2                   9                  8    8.5
# 3                  15                 14   14.5
# 4                  35                 35   35.0
# ..                ...                ...    ...
# 295                29                 30   29.5
# 296                27                 25   26.0
# 297                28                 29   28.5
# 298                16                 18   17.0
# 299                19                 21   20.0
#
# [300 rows x 3 columns]

# %%
print(data[['Test1','Test2']])
# Out:
#      Test1  Test2
# 0     12.5   15.0
# 1     26.5   31.0
# 2      7.0    8.5
# 3     13.5   14.5
# 4     33.0   35.0
# ..     ...    ...
# 295   24.5   29.5
# 296   24.0   26.0
# 297   25.0   28.5
# 298   13.0   17.0
# 299   17.5   20.0
#
# [300 rows x 2 columns]

# %%
def categorize_test1(value):
    if value < 5:
        return 'Severe Dry Eyes'
    elif 5 <= value < 10:
        return 'Moderately Dry Eyes'
    elif 10 <= value < 15:
        return 'Mildly Dry Eyes'
    else:
        return 'Normal'

data['Test1Result'] = data['Test1'].apply(categorize_test1)

# Display the DataFrame with the new 'Test1_Category' column
print(data[['Test1', 'Test1Result']])
# Out:
#      Test1          Test1Result
# 0     12.5      Mildly Dry Eyes
# 1     26.5               Normal
# 2      7.0  Moderately Dry Eyes
# 3     13.5      Mildly Dry Eyes
# 4     33.0               Normal
# ..     ...                  ...
# 295   24.5               Normal
# 296   24.0               Normal
# 297   25.0               Normal
# 298   13.0      Mildly Dry Eyes
# 299   17.5               Normal
#
# [300 rows x 2 columns]

# %%
def categorize_test2(value):
    if value < 3:
        return 'Severe Dry Eyes'
    elif 3 <= value < 6:
        return 'Moderately Dry Eyes'
    elif 6 <= value < 10:
        return 'Mildly Dry Eyes'
    else:
        return 'Normal'

data['Test2Result'] = data['Test2'].apply(categorize_test2)

# Display the DataFrame with the new 'Test1_Category' column
print(data[['Test2', 'Test2Result']])
# Out:
#      Test2      Test2Result
# 0     15.0           Normal
# 1     31.0           Normal
# 2      8.5  Mildly Dry Eyes
# 3     14.5           Normal
# 4     35.0           Normal
# ..     ...              ...
# 295   29.5           Normal
# 296   26.0           Normal
# 297   28.5           Normal
# 298   17.0           Normal
# 299   20.0           Normal
#
# [300 rows x 2 columns]

# %%
print(data[['Test1Result','Test2Result']])
# Out:
#              Test1Result      Test2Result
# 0        Mildly Dry Eyes           Normal
# 1                 Normal           Normal
# 2    Moderately Dry Eyes  Mildly Dry Eyes
# 3        Mildly Dry Eyes           Normal
# 4                 Normal           Normal
# ..                   ...              ...
# 295               Normal           Normal
# 296               Normal           Normal
# 297               Normal           Normal
# 298      Mildly Dry Eyes           Normal
# 299               Normal           Normal
#
# [300 rows x 2 columns]

# %%
def combined_result(row):
    test1 = row['Test1Result']
    test2 = row['Test2Result']
    
    if test1 == test2:
        return test1
    elif test1 == 'Mildly Dry Eyes' and test2 == 'Normal':
        return 'Normal'
    
    elif test1 == 'Moderately Dry Eyes' and test2 == 'Mildly Dry Eyes':
        return 'Mildly Dry Eyes'
    
    elif test1 == 'Severe Dry Eyes' and test2 == 'Moderately Dry Eyes':
        return 'Moderately Dry Eyes'
    
    elif test1 == 'Severe Dry Eyes' and test2 == 'Mildly Dry Eyes':
        return 'Mildly Dry Eyes'
    
    elif test1 == 'Moderately Dry Eyes' and test2 == 'Normal':
        return 'Normal'
    else:
        return 'Indeterminate'

# Apply the combined_result function to each row to determine the combined result
data['Result'] = data.apply(combined_result, axis=1)

# Display the DataFrame with the new 'Result' column
print(data[['Test1Result', 'Test2Result', 'Result']])
# Out:
#              Test1Result      Test2Result           Result
# 0        Mildly Dry Eyes           Normal           Normal
# 1                 Normal           Normal           Normal
# 2    Moderately Dry Eyes  Mildly Dry Eyes  Mildly Dry Eyes
# 3        Mildly Dry Eyes           Normal           Normal
# 4                 Normal           Normal           Normal
# ..                   ...              ...              ...
# 295               Normal           Normal           Normal
# 296               Normal           Normal           Normal
# 297               Normal           Normal           Normal
# 298      Mildly Dry Eyes           Normal           Normal
# 299               Normal           Normal           Normal
#
# [300 rows x 3 columns]

# %%
for index, row in data.iterrows():
    # Access the 'Test1Result' and 'Test2Result' columns and print their values
    print("Test1Result:", row['Test1Result'])
    print("Test2Result:", row['Test2Result'])
# Out:
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Mildly Dry Eyes
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Mildly Dry Eyes
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Severe Dry Eyes
# Test2Result: Mildly Dry Eyes
# Test1Result: Moderately Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Mildly Dry Eyes
# Test1Result: Moderately Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Moderately Dry Eyes
# Test2Result: Mildly Dry Eyes
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal
# Test1Result: Mildly Dry Eyes
# Test2Result: Normal
# Test1Result: Normal
# Test2Result: Normal

# %%
# Assuming you have your DataFrame named 'data'

# Iterate through each row in the DataFrame
for index, row in data.iterrows():
    # Access the 'Result' column and print its value
    print(row['Result'])
# Out:
# Normal
# Normal
# Mildly Dry Eyes
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Mildly Dry Eyes
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Mildly Dry Eyes
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Mildly Dry Eyes
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Mildly Dry Eyes
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal

# %%
# Assuming you want to see all unique values in the 'Ocularsymptomsobservedlately' column
unique_values = data['Result'].unique()

# Print the unique values
print(unique_values)
# Out:
# ['Normal' 'Mildly Dry Eyes']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 32 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Name                                    300 non-null    object
#  1   Age                                     300 non-null    int32
#  2   Sex                                     300 non-null    int32
#  3   wearables                               300 non-null    int32
#  4   Duration                                300 non-null    int32
#  5   onlineplatforms                         300 non-null    int32
#  6   Nature                                  300 non-null    int32
#  7   screenillumination                      300 non-null    int32
#  8   workingyears                            300 non-null    int32
#  9   hoursspentdailycurricular               300 non-null    int32
#  10  hoursspentdailynoncurricular            300 non-null    int32
#  11  Gadgetsused                             300 non-null    int32
#  12  levelofgadjetwithrespecttoeyes          300 non-null    int32
#  13  Distancekeptbetweeneyesandgadjet        300 non-null    int32
#  14  Avgnighttimeusageperday                 300 non-null    int32
#  15  Blinkingduringscreenusage               300 non-null    int32
#  16  Difficultyinfocusingafterusingscreens   300 non-null    int32
#  17  freqquencyofcomplaints                  300 non-null    int32
#  18  Severityofcomplaints                    300 non-null    int32
#  19  Ocularsymptomsobservedlately            300 non-null    int32
#  20  Symptomsobservingatleasthalfofthetimes  300 non-null    int32
#  21  Complaintsfrequency                     300 non-null    int32
#  22  frequencyofdryeyes                      300 non-null    int32
#  23  Schimers1Lefteye                        300 non-null    int32
#  24  Schimers1righteye                       300 non-null    int32
#  25  Schimers2Lefteye                        300 non-null    int32
#  26  Schimers2righteye                       300 non-null    int32
#  27  Test1                                   300 non-null    float64
#  28  Test2                                   300 non-null    float64
#  29  Test1Result                             300 non-null    object
#  30  Test2Result                             300 non-null    object
#  31  Result                                  300 non-null    object
# dtypes: float64(2), int32(26), object(4)
# memory usage: 44.7+ KB
